# %%
# Importação das bibliotecas necessárias
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import EarlyStopping
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# 2025-06-17 00:08:58.357596: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-17 00:08:58.603526: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-17 00:08:58.745437: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750118939.070243    6226 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750118939.139365    6226 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1750118939.765117    6226 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750118939.765156    6226 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750118939.765159    6226 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750118939.765162    6226 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-17 00:08:59.790522: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
## carregamento
df=pd.read_csv('../data/diabetes_dataset.csv')

# %%
df_teste = df.sample(frac=0.05)

# %%
## Limpeza
df.drop('year',axis=1,inplace=True)
df=pd.get_dummies(df,columns=['gender'],drop_first=True)
df['gender_Male']=df['gender_Male'].astype(int)
df['gender_Other']=df['gender_Other'].astype(int)
#df['smoking_history'].unique()

# %%
df.head()
# Out:
#     age location  race:AfricanAmerican  race:Asian  race:Caucasian  \
# 0  32.0  Alabama                     0           0               0
# 1  29.0  Alabama                     0           1               0
# 2  18.0  Alabama                     0           0               0
# 3  41.0  Alabama                     0           0               1
# 4  52.0  Alabama                     1           0               0
#
#    race:Hispanic  race:Other  hypertension  heart_disease smoking_history  \
# 0              0           1             0              0           never
# 1              0           0             0              0           never
# 2              0           1             0              0           never
# 3              0           0             0              0           never
# 4              0           0             0              0           never
#
#      bmi  hbA1c_level  blood_glucose_level  diabetes  gender_Male  \
# 0  27.32          5.0                  100         0            0
# 1  19.95          5.0                   90         0            0
# 2  23.76          4.8                  160         0            1
# 3  27.32          4.0                  159         0            1
# 4  23.75          6.5                   90         0            0
#
#    gender_Other
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
X=df[['age','hypertension','hbA1c_level','bmi','heart_disease','blood_glucose_level']]
y=df['diabetes']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=101)

# %%
## Scalling
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
X_train = scale.fit_transform(X_train)
X_test = scale.fit_transform(X_test)

# %%
## Training

model = Sequential()
model.add(Dense(units=64, activation="relu")) # Escondida
model.add(Dense(units=32, activation="relu")) # Escondida
model.add(Dense(units=16, activation="relu")) # Escondida
model.add(Dense(units=1, activation="sigmoid"))

model.compile(loss="binary_crossentropy", optimizer="SGD")

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor="val_loss", mode="min", patience=20)

# %%
model.fit(x=X_train, 
          y=y_train, 
          epochs=60, 
          validation_data=(X_test, y_test),
          callbacks=[early_stop])
# Out:
# Epoch 1/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.3296 - val_loss: 0.1167
# Epoch 2/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.1166 - val_loss: 0.1115
# Epoch 3/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.1098 - val_loss: 0.1096
# Epoch 4/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.1094 - val_loss: 0.1079
# Epoch 5/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.1058 - val_loss: 0.1065
# Epoch 6/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.1027 - val_loss: 0.1044
# Epoch 7/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.1033 - val_loss: 0.1037
# Epoch 8/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.1019 - val_loss: 0.1017
# Epoch 9/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0973 - val_loss: 0.1007
# Epoch 10/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0994 - val_loss: 0.0990
# Epoch 11/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0965 - val_loss: 0.0984
# Epoch 12/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0974 - val_loss: 0.0982
# Epoch 13/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0937 - val_loss: 0.0960
# Epoch 14/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0948 - val_loss: 0.0950
# Epoch 15/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0927 - val_loss: 0.0967
# Epoch 16/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0904 - val_loss: 0.0939
# Epoch 17/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0913 - val_loss: 0.0928
# Epoch 18/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0883 - val_loss: 0.0920
# Epoch 19/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.0869 - val_loss: 0.0923
# Epoch 20/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0879 - val_loss: 0.0916
# Epoch 21/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0874 - val_loss: 0.0930
# Epoch 22/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0892 - val_loss: 0.0908
# Epoch 23/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0870 - val_loss: 0.0906
# Epoch 24/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0853 - val_loss: 0.0896
# Epoch 25/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0870 - val_loss: 0.0899
# Epoch 26/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0876 - val_loss: 0.0891
# Epoch 27/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0865 - val_loss: 0.0892
# Epoch 28/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0869 - val_loss: 0.0907
# Epoch 29/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0867 - val_loss: 0.0878
# Epoch 30/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0880 - val_loss: 0.0886
# Epoch 31/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0846 - val_loss: 0.0879
# Epoch 32/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0848 - val_loss: 0.0904
# Epoch 33/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0868 - val_loss: 0.0889
# Epoch 34/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0845 - val_loss: 0.0878
# Epoch 35/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0827 - val_loss: 0.0876
# Epoch 36/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0834 - val_loss: 0.0872
# Epoch 37/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0827 - val_loss: 0.0873
# Epoch 38/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0862 - val_loss: 0.0874
# Epoch 39/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.0846 - val_loss: 0.0871
# Epoch 40/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0827 - val_loss: 0.0865
# Epoch 41/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.0831 - val_loss: 0.0863
# Epoch 42/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0848 - val_loss: 0.0878
# Epoch 43/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0838 - val_loss: 0.0879
# Epoch 44/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0848 - val_loss: 0.0874
# Epoch 45/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0833 - val_loss: 0.0873
# Epoch 46/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0843 - val_loss: 0.0861
# Epoch 47/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0814 - val_loss: 0.0863
# Epoch 48/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0837 - val_loss: 0.0865
# Epoch 49/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0826 - val_loss: 0.0861
# Epoch 50/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0822 - val_loss: 0.0857
# Epoch 51/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0851 - val_loss: 0.0863
# Epoch 52/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0844 - val_loss: 0.0852
# Epoch 53/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0830 - val_loss: 0.0863
# Epoch 54/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0817 - val_loss: 0.0876
# Epoch 55/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0853 - val_loss: 0.0859
# Epoch 56/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0841 - val_loss: 0.0859
# Epoch 57/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0822 - val_loss: 0.0870
# Epoch 58/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0834 - val_loss: 0.0860
# Epoch 59/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0814 - val_loss: 0.0854
# Epoch 60/60
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0824 - val_loss: 0.0850

# %%
model_loss = pd.DataFrame(model.history.history)
model_loss.plot()
# Out:
# <Axes: >

# %%
preds = (model.predict(X_test)).astype("int32")
# Out:
# 163/938 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 666us/step

# %%
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97     27422
#            1       1.00      0.32      0.49      2578
#
#     accuracy                           0.94     30000
#    macro avg       0.97      0.66      0.73     30000
# weighted avg       0.95      0.94      0.93     30000

# %% [markdown]
# Exemplo de registro:
# *  age : 40
# *  hypertension : 1
# *  hbA1c_leve : 6.5
# *  bmi : 28.9
# *  heart_disease : 0
# *  blood_glucose_level : 166

# %%
## Predicting

prediction=(model.predict(scale.transform(np.array([[40,1,6.5,28.9,0,166]])))).astype('int32')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# /workspaces/ml-supervised-dev/venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
prediction
# Out:
# array([[0]], dtype=int32)
